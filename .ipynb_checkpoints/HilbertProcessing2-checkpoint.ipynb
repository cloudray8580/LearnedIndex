# %%
# first level direction: alwasy left
# generate clock wise
def xy2d(n, x, y):
    d = 0
    s = int(n / 2)
    while s > 0:
        rx = (x & s) > 0
        ry = (y & s) > 0
        if rx == 0 and ry == 0:
            d += 0
        if rx == 1 and ry == 0:
            d += s*s
        if rx == 1 and ry == 1:
            d += s*s*2
        if rx == 0 and ry == 1:
            d += s*s*3   
#         d += s * s * ((3 * rx) ^ ry)
        x,y = rot(s, x, y, rx, ry)
        s = int(s/2)
    return d

# def d2xy(n, d):
#     t = d
#     x = 0
#     y = 0
#     s = 1
#     while s < n:
#         rx = 1 & int(t/2)
#         ry = 1 & (t^rx)
#         x,y = rot(s, x, y, rx, ry)
#         x += s * rx
#         y += s * ry
#         t = int(t/4)
#         s *= 2
#     return x, y

def rot(n, x, y, rx, ry):
    if rx == 0 : # the upper level direction remains the same, so only change the lower level
        if ry == 1 :
            x = n-1 - x
            y = n-1 - y
        t  = x
        x = y
        y = t
    return x, y

# ===== Testing =====
# for i in range(8):
#     for j in range(8):
#         print(xy2d(8, i, j))

# %%
from enum import Enum
class Direction(Enum):
    UP = 0
    LEFT = 1
    RIGHT = 2
    DOWN = 3

class ClockDirection(Enum):
    CLOCKWISE = 0
    COUNTERCLOCKWISE = 1
    UNAVAILABLE = 2

class Quadrant(Enum):
    LOWERLEFT = 0
    LOWERRIGHT = 1
    UPPERRIGHT = 2
    UPPERLEFT = 3
    
next_level_direction=[[Direction.UP, Direction.UP, Direction.RIGHT, Direction.LEFT],
                      [Direction.DOWN, Direction.LEFT, Direction.LEFT, Direction.UP],
                      [Direction.RIGHT, Direction.DOWN, Direction.UP, Direction.RIGHT],
                      [Direction.LEFT, Direction.RIGHT, Direction.DOWN, Direction.DOWN]]

next_level_clock_direction = [[ClockDirection.CLOCKWISE,ClockDirection.COUNTERCLOCKWISE,ClockDirection.COUNTERCLOCKWISE,ClockDirection.UNAVAILABLE],
                           [ClockDirection.CLOCKWISE,ClockDirection.COUNTERCLOCKWISE,ClockDirection.UNAVAILABLE,ClockDirection.CLOCKWISE],
                           [ClockDirection.CLOCKWISE,ClockDirection.UNAVAILABLE,ClockDirection.COUNTERCLOCKWISE,ClockDirection.CLOCKWISE],
                           [ClockDirection.UNAVAILABLE,ClockDirection.COUNTERCLOCKWISE,ClockDirection.COUNTERCLOCKWISE,ClockDirection.CLOCKWISE]]

# ===== Testing =====
# for i in range(4):
#     for j in range(4):
#         print(next_level_direction[i][j])
# vard = Direction.UP
# if vard.name == "UP":
#     print("yes") # yes
# print(vard.name)
# print(vard.value)
# if vard == Direction.UP:
#     print("yes")
# for dir in Direction:
#     print(dir)

# %%
# dictionary for interval:
# lower_x
# upper_X
# lower_y
# upper_y
# lower_hilbert
# upper_hilbert


def range_decompose(max_bits, current_bits, down_x, up_x, down_y, up_y, center_x, center_y, pre_dir, this_dir, intervals):
    
    # if there is only 1 element here
    if current_bits == 0:
        hvalue = xy2d(1<<max_bits, down_x, down_y)
        interval = {"lower_x":down_x, "upper_x":up_x, "lower_y":down_y,"upper_y":up_y,"lower_hilbert":hvalue,"upper_hilbert":hvalue}
        intervals.append(interval);
        return
    
    half_region = 1 << (current_bits - 1)
    clock_dir = next_level_clock_direction[pre_dir.value][this_dir.value]
    if current_bits == max_bits:
        clocl_dir = ClockDirection.COUNTERCLOCKWISE
        
    # check if the range contains the entire region
    if down_x == center_x - half_region and down_y == center_y - half_region and up_x == center_x + half_region-1 and up_y == center_y + half_region-1:
        # if yes, return this region as an interval
        lower_x = 0
        upper_x = 0
        lower_y = 0
        upper_y = 0
        if clock_dir.name == "CLOCKWISE":
            if this_dir.name == "UP":
                lower_x = up_x
                upper_x = down_x
                lower_y = up_y
                upper_y = up_y
            elif this_dir.name == "LEFT":
                lower_x = down_x
                upper_x = down_x
                lower_y = up_y
                upper_y = down_y
            elif this_dir.name == "RIGHT":
                lower_x = up_x
                upper_x = up_x
                lower_y = down_y
                upper_y = up_y
            elif this_dir.name == "DOWN":
                lower_x = down_x
                upper_x = up_x
                lower_y = down_y
                upper_y = down_y
        elif clock_dir.name == "COUNTERCLOCKWISE":
            if this_dir.name == "UP":
                lower_x = down_x
                upper_x = up_x
                lower_y = up_y
                upper_y = up_y
            elif this_dir.name == "LEFT":
                lower_x = down_x
                upper_x = down_x
                lower_y = down_y
                upper_y = up_y
            elif this_dir.name == "RIGHT":
                lower_x = up_x
                upper_x = up_x
                lower_y = up_y
                upper_y = down_y
            elif this_dir.name == "DOWN":
                lower_x = up_x
                upper_x = down_x
                lower_y = down_y
                upper_y = down_y
                
        lowhvalue = xy2d(1<<max_bits,lower_x,lower_y)
        uphvalue = xy2d(1<<max_bits,upper_x,upper_y)
        interval = {"lower_x":lower_x, "upper_x":upper_x, "lower_y":lower_y,"upper_y":upper_y,"lower_hilbert":lowhvalue,"upper_hilbert":uphvalue}
        intervals.append(interval)
    else:
        # if not, further decompose it
        current_bits -= 1
        if current_bits <= 0:
            half_region = 0
        else:
            half_region = 1 << (current_bits - 1)
        
        if clock_dir.name == "CLOCKWISE":
            if this_dir.name == "UP":
                parent_dir = Direction.UP
                if up_x >= center_x and up_y >= center_y: # upper right
                    quad = Quadrant.UPPERRIGHT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, max(center_x,down_x), up_x, max(center_y,down_y), up_y, center_x+half_region, center_y+half_region, parent_dir, child_dir, intervals)
                if up_x >= center_x and down_y < center_y: # lower right
                    quad = Quadrant.LOWERRIGHT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, max(center_x,down_x), up_x, down_y, min(center_y-1,up_y), center_x+half_region, center_y-half_region, parent_dir, child_dir, intervals)
                if down_x < center_x and down_y < center_y: # lower left\
                    quad = Quadrant.LOWERLEFT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, down_x, min(center_x-1,up_x), down_y, min(center_y-1,up_y), center_x-half_region, center_y-half_region, parent_dir, child_dir, intervals)
                if down_x < center_x and up_y >= center_y: # upper left
                    quad = Quadrant.UPPERLEFT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, down_x, min(center_x-1,up_x), max(center_y,down_y), up_y, center_x-half_region, center_y+half_region, parent_dir, child_dir, intervals)
            elif this_dir.name == "LEFT":
                parent_dir = Direction.LEFT
                if down_x < center_x and up_y >= center_y: # upper left
                    quad = Quadrant.UPPERLEFT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, down_x, min(center_x-1,up_x), max(center_y,down_y), up_y, center_x-half_region, center_y+half_region, parent_dir, child_dir, intervals)
                if up_x >= center_x and up_y >= center_y: # upper right
                    quad = Quadrant.UPPERRIGHT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, max(center_x,down_x), up_x, max(center_y,down_y), up_y, center_x+half_region, center_y+half_region, parent_dir, child_dir, intervals)
                if up_x >= center_x and down_y < center_y: # lower right
                    quad = Quadrant.LOWERRIGHT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, max(center_x,down_x), up_x, down_y, min(center_y-1,up_y), center_x+half_region, center_y-half_region, parent_dir, child_dir, intervals)
                if down_x < center_x and down_y < center_y: # lower left\
                    quad = Quadrant.LOWERLEFT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, down_x, min(center_x-1,up_x), down_y, min(center_y-1,up_y), center_x-half_region, center_y-half_region, parent_dir, child_dir, intervals)
            elif this_dir.name == "RIGHT":
                parent_dir = Direction.RIGHT
                if up_x >= center_x and down_y < center_y: # lower right
                    quad = Quadrant.LOWERRIGHT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, max(center_x,down_x), up_x, down_y, min(center_y-1,up_y), center_x+half_region, center_y-half_region, parent_dir, child_dir, intervals)
                if down_x < center_x and down_y < center_y: # lower left\
                    quad = Quadrant.LOWERLEFT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, down_x, min(center_x-1,up_x), down_y, min(center_y-1,up_y), center_x-half_region, center_y-half_region, parent_dir, child_dir, intervals)
                if down_x < center_x and up_y >= center_y: # upper left
                    quad = Quadrant.UPPERLEFT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, down_x, min(center_x-1,up_x), max(center_y,down_y), up_y, center_x-half_region, center_y+half_region, parent_dir, child_dir, intervals)
                if up_x >= center_x and up_y >= center_y: # upper right
                    quad = Quadrant.UPPERRIGHT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, max(center_x,down_x), up_x, max(center_y,down_y), up_y, center_x+half_region, center_y+half_region, parent_dir, child_dir, intervals)
            elif this_dir.name == "DOWN":
                parent_dir = Direction.DOWN
                if down_x < center_x and down_y < center_y: # lower left\
                    quad = Quadrant.LOWERLEFT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, down_x, min(center_x-1,up_x), down_y, min(center_y-1,up_y), center_x-half_region, center_y-half_region, parent_dir, child_dir, intervals)
                if down_x < center_x and up_y >= center_y: # upper left
                    quad = Quadrant.UPPERLEFT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, down_x, min(center_x-1,up_x), max(center_y,down_y), up_y, center_x-half_region, center_y+half_region, parent_dir, child_dir, intervals)
                if up_x >= center_x and up_y >= center_y: # upper right
                    quad = Quadrant.UPPERRIGHT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, max(center_x,down_x), up_x, max(center_y,down_y), up_y, center_x+half_region, center_y+half_region, parent_dir, child_dir, intervals)
                if up_x >= center_x and down_y < center_y: # lower right
                    quad = Quadrant.LOWERRIGHT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, max(center_x,down_x), up_x, down_y, min(center_y-1,up_y), center_x+half_region, center_y-half_region, parent_dir, child_dir, intervals)
        elif clock_dir.name == "COUNTERCLOCKWISE":
            if this_dir.name == "UP":
                parent_dir = Direction.UP
                if down_x < center_x and up_y >= center_y: # upper left
                    quad = Quadrant.UPPERLEFT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, down_x, min(center_x-1,up_x), max(center_y,down_y), up_y, center_x-half_region, center_y+half_region, parent_dir, child_dir, intervals)
                if down_x < center_x and down_y < center_y: # lower left\
                    quad = Quadrant.LOWERLEFT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, down_x, min(center_x-1,up_x), down_y, min(center_y-1,up_y), center_x-half_region, center_y-half_region, parent_dir, child_dir, intervals)
                if up_x >= center_x and down_y < center_y: # lower right
                    quad = Quadrant.LOWERRIGHT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, max(center_x,down_x), up_x, down_y, min(center_y-1,up_y), center_x+half_region, center_y-half_region, parent_dir, child_dir, intervals)
                if up_x >= center_x and up_y >= center_y: # upper right
                    quad = Quadrant.UPPERRIGHT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, max(center_x,down_x), up_x, max(center_y,down_y), up_y, center_x+half_region, center_y+half_region, parent_dir, child_dir, intervals)
            elif this_dir.name == "LEFT":
                parent_dir = Direction.LEFT
                if down_x < center_x and down_y < center_y: # lower left
                    quad = Quadrant.LOWERLEFT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, down_x, min(center_x-1,up_x), down_y, min(center_y-1,up_y), center_x-half_region, center_y-half_region, parent_dir, child_dir, intervals)
                if up_x >= center_x and down_y < center_y: # lower right
                    quad = Quadrant.LOWERRIGHT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, max(center_x,down_x), up_x, down_y, min(center_y-1,up_y), center_x+half_region, center_y-half_region, parent_dir, child_dir, intervals)
                if up_x >= center_x and up_y >= center_y: # upper right
                    quad = Quadrant.UPPERRIGHT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, max(center_x,down_x), up_x, max(center_y,down_y), up_y, center_x+half_region, center_y+half_region, parent_dir, child_dir, intervals)
                if down_x < center_x and up_y >= center_y: # upper left
                    quad = Quadrant.UPPERLEFT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, down_x, min(center_x-1,up_x), max(center_y,down_y), up_y, center_x-half_region, center_y+half_region, parent_dir, child_dir, intervals)
            elif this_dir.name == "RIGHT":
                parent_dir = Direction.RIGHT
                if up_x >= center_x and up_y >= center_y: # upper right
                    quad = Quadrant.UPPERRIGHT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, max(center_x,down_x), up_x, max(center_y,down_y), up_y, center_x+half_region, center_y+half_region, parent_dir, child_dir, intervals)
                if down_x < center_x and up_y >= center_y: # upper left
                    quad = Quadrant.UPPERLEFT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, down_x, min(center_x-1,up_x), max(center_y,down_y), up_y, center_x-half_region, center_y+half_region, parent_dir, child_dir, intervals)
                if down_x < center_x and down_y < center_y: # lower left
                    quad = Quadrant.LOWERLEFT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, down_x, min(center_x-1,up_x), down_y, min(center_y-1,up_y), center_x-half_region, center_y-half_region, parent_dir, child_dir, intervals)
                if up_x >= center_x and down_y < center_y: # lower right
                    quad = Quadrant.LOWERRIGHT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, max(center_x,down_x), up_x, down_y, min(center_y-1,up_y), center_x+half_region, center_y-half_region, parent_dir, child_dir, intervals)
            elif this_dir.name == "DOWN":
                parent_dir = Direction.DOWN
                if up_x >= center_x and down_y < center_y: # lower right
                    quad = Quadrant.LOWERRIGHT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, max(center_x,down_x), up_x, down_y, min(center_y-1,up_y), center_x+half_region, center_y-half_region, parent_dir, child_dir, intervals)
                if up_x >= center_x and up_y >= center_y: # upper right
                    quad = Quadrant.UPPERRIGHT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, max(center_x,down_x), up_x, max(center_y,down_y), up_y, center_x+half_region, center_y+half_region, parent_dir, child_dir, intervals)
                if down_x < center_x and up_y >= center_y: # upper left
                    quad = Quadrant.UPPERLEFT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, down_x, min(center_x-1,up_x), max(center_y,down_y), up_y, center_x-half_region, center_y+half_region, parent_dir, child_dir, intervals)
                if down_x < center_x and down_y < center_y: # lower left
                    quad = Quadrant.LOWERLEFT
                    child_dir = next_level_direction[parent_dir.value][quad.value]
                    range_decompose(max_bits, current_bits, down_x, min(center_x-1,up_x), down_y, min(center_y-1,up_y), center_x-half_region, center_y-half_region, parent_dir, child_dir, intervals)

# ===== Testing =====
# intervals = []
# range_decompose(3,3,2,4,2,4,4,4,Direction.LEFT,Direction.LEFT,intervals)
# range_decompose(3,0,2,4,2,4,4,4,Direction.LEFT,Direction.LEFT,intervals)
# range_decompose(3,1,2,3,2,3,3,3,Direction.LEFT,Direction.LEFT,intervals)
# range_decompose(3,1,2,3,2,3,3,3,Direction.DOWN,Direction.DOWN,intervals)
# print(intervals)

# import ipdb
# ipdb.set_trace()
# intervals = []
# range_decompose(3,3,0,3,0,7,4,4,Direction.LEFT,Direction.LEFT,intervals)
# print(len(intervals))
# intervals = intervals[0]
# print(intervals[0])
# print(intervals[0]["lower_x"])
# for inter in intervals:
#     print(intervals)

# %%
def merge_intervals(intervals):
    if len(intervals) <= 1:
        return intervals
    merged_intervals = []
    i = 0
    j = 0
    while i < len(intervals):
        temp_upper = intervals[i]["upper_hilbert"]
        j = 1
        while i+j < len(intervals) and intervals[i+j]["lower_hilbert"] == temp_upper + 1:
            temp_upper = intervals[i+j]["upper_hilbert"]
            j += 1
        interval = {"lower_x":intervals[i]["lower_x"], "upper_x":intervals[i+j-1]["upper_x"], 
                    "lower_y":intervals[i]["lower_y"],"upper_y":intervals[i+j-1]["upper_y"],
                    "lower_hilbert":intervals[i]["lower_hilbert"],"upper_hilbert":intervals[i+j-1]["upper_hilbert"]}
        merged_intervals.append(interval)
        i += j
    return merged_intervals

def get_intervals(lower_x, upper_x, lower_y, upper_y, max_bits = 22):
    intervals = []
    range_decompose(max_bits,max_bits,lower_x,upper_x,lower_y,upper_y,1<<(max_bits-1),1<<(max_bits-1),Direction.LEFT,Direction.LEFT,intervals)
    intervals = merge_intervals(intervals)
    return intervals
    
# ===== Testing =====
#print(get_intervals(2,4,2,4))

# %%
# ===== Testing =====
# import ipdb
# ipdb.set_trace()
# intervals = []
# range_decompose(3,3,2,4,2,4,4,4,Direction.LEFT,Direction.LEFT,intervals)
# print(intervals)
# intervals = merge_intervals(intervals)
# print(intervals)

# %%
# print(xy2d(4194306, 1600000, 1900000))

# %%
import pandas as pd
df = pd.read_csv("./Data/HilbertSortedPOIs.csv")
print(df)
TOTAL = len(df)+1
COL = df.columns

import numpy as np
print(np.any(np.isnan(df))) # should be false
print(np.all(np.isfinite(df))) # should be true
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
print(scaler.fit(df.iloc[:,0:5]))
print(scaler.mean_)
df.iloc[:,0:5]=scaler.transform(df.iloc[:,0:5])
print(df)

# df1 = pd.DataFrame(data=[[-76.3099,22.4995,273802,2024995,17344470968016]], columns=["x","y","x_","y_","hilbert"],index=[0], dtype=object)
# df1 = pd.DataFrame(data=[[-10,10,1600000,1900000,2819270465194]], columns=["x","y","x_","y_","hilbert"],index=[0], dtype=object)
# 1157562 -2.342780  1.971747 -2.342779  1.971747  2.001347  1157562         NaN
# 1157563 -2.356395  1.966156 -2.356395  1.966155  2.001356  1157563         NaN
# 1157564 -2.304691  1.998923 -2.304690  1.998923  2.001494  1157564         NaN
# 1157565 -2.313176  1.999324 -2.313176  1.999323  2.001520  1157565         NaN
# 1157566 -2.323656  1.998676 -2.323656  1.998676  2.001524  1157566         NaN
# 1157567 -2.323656  1.998676 -2.323656  1.998676  2.001524  1157567         NaN
# 1157568 -2.324059  1.998911 -2.324059  1.998912  2.001525  1157568         NaN
# 1157569 -3.821717  0.160992 -3.821717  0.160992  2.111776  1157569         NaN
#
# [1157570 rows x 7 columns]
#          x        y      x_       y_         hilbert
# 0 -76.3099  22.4995  273802  2024995  17344470968016
#           x         y        x_        y_   hilbert
# 0 -3.821717  0.160992 -3.821717  0.160992  2.111776
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# D:\anaconda\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
from sklearn import linear_model
from sklearn import neural_network
from sklearn import ensemble
import ipdb
import time
stages = [1,1000]
index = []
data = []

start_time=time.time()

for i in range(len(stages)):
    temp = []
    for j in range(stages[i]):
        df_ = pd.DataFrame(columns=COL)
        temp.append(df_)
    data.append(temp)
    
data[0][0] = df
nodatacount = 0

for i in range(len(stages)):
    temp = []
    print("======stage:"+str(i)+"======")
    
    for j in range(stages[i]):
        print("model:"+str(j))
        if len(data[i][j]) == 0:
            nodatacount += 1
            data[i][j] = data[i][j-1]
            print(j)
#         lr = linear_model.LinearRegression()
#         lr = linear_model.ElasticNet(max_iter=10000)
#         lr = linear_model.Lasso(max_iter=10000)
#         lr = ensemble.GradientBoostingRegressor()
#         lr = ensemble.AdaBoostRegressor()
        if i == 0:
#             lr = neural_network.MLPRegressor(hidden_layer_sizes=(8, 2),max_iter=1000)
            lr = ensemble.GradientBoostingRegressor(n_estimators=500)
        else:
            lr = ensemble.GradientBoostingRegressor()
        train_x = data[i][j].iloc[:,4].reshape(-1,1)
#         train_x = data[i][j].iloc[:,0:5]
        train_y = data[i][j].iloc[:,5]
        lr.fit(train_x,train_y)
        temp.append(lr)
        # allocate data
        if i < len(stages)-1:
            predicted = lr.predict(train_x)
            for pi in range(len(predicted)): # do not change the prediction
                #print(item)
                if predicted[pi] < 0:
                    predicted[pi] = 0
                if predicted[pi] >= TOTAL:
                    predicted[pi] = TOTAL-1   
            ModelID = ((predicted/TOTAL)*stages[i+1]).astype(int)
            data[i][j].iloc[:,-1]=ModelID
#             if i == 1 and np.any(data[i][j]['prediction'] == 4):
#                 print(j)

            for k in range(stages[i+1]):
                data[i+1][k] = data[i+1][k].append(data[i][j].loc[data[i][j]['prediction'] == k])
    index.append(temp)

elapsed_time = time.time() - start_time
print(elapsed_time)
print(nodatacount)
# Out:
# ======stage:0======
# model:0
# D:\anaconda\lib\site-packages\ipykernel_launcher.py:42: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# ======stage:1======
# model:0
# model:1
# model:2
# model:3
# model:4
# model:5
# model:6
# model:7
# model:8
# model:9
# model:10
# model:11
# model:12
# model:13
# model:14
# model:15
# model:16
# 16
# model:17
# model:18
# model:19
# 19
# model:20
# model:21
# 21
# model:22
# model:23
# model:24
# 24
# model:25
# 25
# model:26
# model:27
# 27
# model:28
# 28
# model:29
# model:30
# 30
# model:31
# 31
# model:32
# model:33
# model:34
# model:35
# 35
# model:36
# 36
# model:37
# model:38
# model:39
# 39
# model:40
# model:41
# 41
# model:42
# 42
# model:43
# 43
# model:44
# model:45
# model:46
# model:47
# 47
# model:48
# 48
# model:49
# model:50
# model:51
# 51
# model:52
# 52
# model:53
# model:54
# 54
# model:55
# model:56
# model:57
# model:58
# model:59
# 59
# model:60
# 60
# model:61
# 61
# model:62
# model:63
# model:64
# 64
# model:65
# 65
# model:66
# model:67
# model:68
# model:69
# 69
# model:70
# 70
# model:71
# model:72
# model:73
# model:74
# model:75
# model:76
# model:77
# model:78
# 78
# model:79
# 79
# model:80
# model:81
# model:82
# model:83
# model:84
# model:85
# model:86
# model:87
# 87
# model:88
# 88
# model:89
# model:90
# 90
# model:91
# model:92
# 92
# model:93
# 93
# model:94
# model:95
# 95
# model:96
# model:97
# model:98
# model:99
# model:100
# model:101
# 101
# model:102
# 102
# model:103
# 103
# model:104
# model:105
# 105
# model:106
# model:107
# model:108
# model:109
# 109
# model:110
# 110
# model:111
# model:112
# model:113
# model:114
# 114
# model:115
# model:116
# 116
# model:117
# 117
# model:118
# model:119
# model:120
# model:121
# model:122
# model:123
# model:124
# 124
# model:125
# 125
# model:126
# model:127
# model:128
# model:129
# model:130
# model:131
# model:132
# model:133
# model:134
# model:135
# model:136
# model:137
# model:138
# model:139
# model:140
# model:141
# 141
# model:142
# 142
# model:143
# model:144
# model:145
# model:146
# model:147
# model:148
# model:149
# model:150
# 150
# model:151
# 151
# model:152
# model:153
# model:154
# model:155
# model:156
# model:157
# 157
# model:158
# 158
# model:159
# 159
# model:160
# model:161
# model:162
# model:163
# model:164
# 164
# model:165
# model:166
# model:167
# 167
# model:168
# model:169
# model:170
# 170
# model:171
# 171
# model:172
# 172
# model:173
# model:174
# 174
# model:175
# model:176
# 176
# model:177
# model:178
# 178
# model:179
# 179
# model:180
# model:181
# model:182
# model:183
# 183
# model:184
# 184
# model:185
# model:186
# model:187
# 187
# model:188
# 188
# model:189
# model:190
# 190
# model:191
# 191
# model:192
# model:193
# model:194
# 194
# model:195
# 195
# model:196
# 196
# model:197
# model:198
# model:199
# model:200
# model:201
# model:202
# 202
# model:203
# 203
# model:204
# 204
# model:205
# model:206
# model:207
# model:208
# model:209
# model:210
# model:211
# 211
# model:212
# 212
# model:213
# 213
# model:214
# model:215
# model:216
# model:217
# 217
# model:218
# model:219
# 219
# model:220
# 220
# model:221
# model:222
# model:223
# model:224
# model:225
# 225
# model:226
# 226
# model:227
# model:228
# model:229
# model:230
# model:231
# model:232
# 232
# model:233
# 233
# model:234
# 234
# model:235
# 235
# model:236
# model:237
# 237
# model:238
# model:239
# 239
# model:240
# 240
# model:241
# model:242
# 242
# model:243
# model:244
# model:245
# model:246
# model:247
# model:248
# model:249
# 249
# model:250
# 250
# model:251
# model:252
# model:253
# model:254
# model:255
# model:256
# 256
# model:257
# 257
# model:258
# 258
# model:259
# model:260
# model:261
# model:262
# model:263
# model:264
# model:265
# 265
# model:266
# 266
# model:267
# model:268
# model:269
# model:270
# model:271
# model:272
# 272
# model:273
# 273
# model:274
# 274
# model:275
# 275
# model:276
# 276
# model:277
# model:278
# model:279
# model:280
# 280
# model:281
# 281
# model:282
# 282
# model:283
# 283
# model:284
# model:285
# model:286
# model:287
# model:288
# model:289
# 289
# model:290
# 290
# model:291
# 291
# model:292
# model:293
# model:294
# model:295
# 295
# model:296
# model:297
# 297
# model:298
# 298
# model:299
# 299
# model:300
# model:301
# 301
# model:302
# 302
# model:303
# 303
# model:304
# 304
# model:305
# model:306
# 306
# model:307
# 307
# model:308
# 308
# model:309
# 309
# model:310
# model:311
# 311
# model:312
# 312
# model:313
# 313
# model:314
# model:315
# model:316
# model:317
# model:318
# 318
# model:319
# 319
# model:320
# 320
# model:321
# 321
# model:322
# 322
# model:323
# model:324
# model:325
# model:326
# model:327
# model:328
# model:329
# 329
# model:330
# 330
# model:331
# model:332
# model:333
# model:334
# model:335
# model:336
# 336
# model:337
# 337
# model:338
# 338
# model:339
# model:340
# model:341
# model:342
# model:343
# model:344
# 344
# model:345
# model:346
# model:347
# model:348
# model:349
# model:350
# model:351
# 351
# model:352
# model:353
# 353
# model:354
# model:355
# 355
# model:356
# 356
# model:357
# model:358
# 358
# model:359
# 359
# model:360
# model:361
# 361
# model:362
# 362
# model:363
# 363
# model:364
# 364
# model:365
# model:366
# model:367
# 367
# model:368
# 368
# model:369
# model:370
# model:371
# model:372
# model:373
# 373
# model:374
# 374
# model:375
# 375
# model:376
# 376
# model:377
# model:378
# model:379
# model:380
# model:381
# model:382
# model:383
# 383
# model:384
# 384
# model:385
# 385
# model:386
# model:387
# 387
# model:388
# model:389
# model:390
# 390
# model:391
# 391
# model:392
# 392
# model:393
# model:394
# model:395
# 395
# model:396
# model:397
# 397
# model:398
# 398
# model:399
# 399
# model:400
# 400
# model:401
# model:402
# model:403
# model:404
# model:405
# model:406
# model:407
# 407
# model:408
# 408
# model:409
# 409
# model:410
# model:411
# model:412
# model:413
# model:414
# model:415
# model:416
# 416
# model:417
# 417
# model:418
# 418
# model:419
# 419
# model:420
# model:421
# model:422
# model:423
# 423
# model:424
# 424
# model:425
# 425
# model:426
# 426
# model:427
# 427
# model:428
# model:429
# model:430
# 430
# model:431
# model:432
# 432
# model:433
# 433
# model:434
# 434
# model:435
# model:436
# model:437
# model:438
# model:439
# model:440
# 440
# model:441
# model:442
# model:443
# 443
# model:444
# 444
# model:445
# 445
# model:446
# model:447
# 447
# model:448
# model:449
# 449
# model:450
# 450
# model:451
# 451
# model:452
# model:453
# model:454
# model:455
# 455
# model:456
# 456
# model:457
# 457
# model:458
# 458
# model:459
# model:460
# model:461
# 461
# model:462
# 462
# model:463
# 463
# model:464
# 464
# model:465
# 465
# model:466
# model:467
# model:468
# model:469
# 469
# model:470
# 470
# model:471
# 471
# model:472
# 472
# model:473
# 473
# model:474
# model:475
# model:476
# 476
# model:477
# model:478
# model:479
# model:480
# model:481
# 481
# model:482
# 482
# model:483
# 483
# model:484
# 484
# model:485
# model:486
# model:487
# model:488
# 488
# model:489
# 489
# model:490
# 490
# model:491
# 491
# model:492
# model:493
# model:494
# model:495
# model:496
# model:497
# model:498
# model:499
# 499
# model:500
# 500
# model:501
# model:502
# model:503
# model:504
# model:505
# model:506
# model:507
# model:508
# model:509
# model:510
# 510
# model:511
# 511
# model:512
# 512
# model:513
# 513
# model:514
# model:515
# model:516
# model:517
# 517
# model:518
# model:519
# model:520
# model:521
# 521
# model:522
# 522
# model:523
# 523
# model:524
# 524
# model:525
# 525
# model:526
# model:527
# model:528
# 528
# model:529
# 529
# model:530
# 530
# model:531
# model:532
# 532
# model:533
# 533
# model:534
# 534
# model:535
# 535
# model:536
# model:537
# model:538
# 538
# model:539
# 539
# model:540
# 540
# model:541
# model:542
# model:543
# 543
# model:544
# 544
# model:545
# 545
# model:546
# model:547
# 547
# model:548
# model:549
# 549
# model:550
# 550
# model:551
# model:552
# 552
# model:553
# 553
# model:554
# model:555
# 555
# model:556
# model:557
# 557
# model:558
# 558
# model:559
# 559
# model:560
# 560
# model:561
# model:562
# 562
# model:563
# 563
# model:564
# 564
# model:565
# 565
# model:566
# 566
# model:567
# 567
# model:568
# model:569
# 569
# model:570
# 570
# model:571
# model:572
# model:573
# model:574
# model:575
# 575
# model:576
# 576
# model:577
# 577
# model:578
# model:579
# model:580
# model:581
# model:582
# model:583
# model:584
# 584
# model:585
# model:586
# model:587
# 587
# model:588
# model:589
# 589
# model:590
# 590
# model:591
# 591
# model:592
# 592
# model:593
# model:594
# 594
# model:595
# 595
# model:596
# model:597
# model:598
# model:599
# model:600
# 600
# model:601
# 601
# model:602
# model:603
# model:604
# model:605
# 605
# model:606
# 606
# model:607
# 607
# model:608
# model:609
# model:610
# model:611
# model:612
# model:613
# 613
# model:614
# 614
# model:615
# 615
# model:616
# 616
# model:617
# model:618
# model:619
# model:620
# model:621
# model:622
# model:623
# model:624
# model:625
# model:626
# model:627
# 627
# model:628
# 628
# model:629
# model:630
# model:631
# model:632
# model:633
# model:634
# model:635
# 635
# model:636
# 636
# model:637
# model:638
# model:639
# 639
# model:640
# 640
# model:641
# 641
# model:642
# 642
# model:643
# 643
# model:644
# model:645
# model:646
# model:647
# 647
# model:648
# 648
# model:649
# 649
# model:650
# model:651
# model:652
# model:653
# 653
# model:654
# 654
# model:655
# 655
# model:656
# 656
# model:657
# model:658
# model:659
# model:660
# model:661
# 661
# model:662
# 662
# model:663
# model:664
# model:665
# model:666
# model:667
# model:668
# model:669
# model:670
# model:671
# model:672
# 672
# model:673
# 673
# model:674
# 674
# model:675
# 675
# model:676
# model:677
# 677
# model:678
# model:679
# 679
# model:680
# 680
# model:681
# 681
# model:682
# model:683
# 683
# model:684
# 684
# model:685
# model:686
# 686
# model:687
# 687
# model:688
# model:689
# model:690
# model:691
# model:692
# model:693
# 693
# model:694
# 694
# model:695
# model:696
# 696
# model:697
# 697
# model:698
# model:699
# model:700
# model:701
# model:702
# 702
# model:703
# 703
# model:704
# model:705
# model:706
# model:707
# model:708
# model:709
# model:710
# 710
# model:711
# 711
# model:712
# 712
# model:713
# 713
# model:714
# model:715
# model:716
# model:717
# model:718
# 718
# model:719
# model:720
# model:721
# model:722
# 722
# model:723
# 723
# model:724
# 724
# model:725
# model:726
# model:727
# model:728
# model:729
# model:730
# model:731
# model:732
# 732
# model:733
# 733
# model:734
# model:735
# model:736
# model:737
# model:738
# model:739
# model:740
# 740
# model:741
# 741
# model:742
# 742
# model:743
# 743
# model:744
# 744
# model:745
# 745
# model:746
# 746
# model:747
# 747
# model:748
# 748
# model:749
# model:750
# 750
# model:751
# 751
# model:752
# 752
# model:753
# 753
# model:754
# 754
# model:755
# 755
# model:756
# 756
# model:757
# 757
# model:758
# 758
# model:759
# 759
# model:760
# 760
# model:761
# model:762
# 762
# model:763
# 763
# model:764
# 764
# model:765
# 765
# model:766
# model:767
# 767
# model:768
# 768
# model:769
# model:770
# 770
# model:771
# 771
# model:772
# 772
# model:773
# model:774
# model:775
# 775
# model:776
# model:777
# model:778
# 778
# model:779
# 779
# model:780
# 780
# model:781
# 781
# model:782
# 782
# model:783
# model:784
# 784
# model:785
# model:786
# model:787
# 787
# model:788
# 788
# model:789
# 789
# model:790
# 790
# model:791
# 791
# model:792
# 792
# model:793
# 793
# model:794
# model:795
# 795
# model:796
# model:797
# 797
# model:798
# 798
# model:799
# 799
# model:800
# 800
# model:801
# 801
# model:802
# model:803
# 803
# model:804
# 804
# model:805
# model:806
# model:807
# 807
# model:808
# 808
# model:809
# 809
# model:810
# model:811
# model:812
# model:813
# model:814
# 814
# model:815
# 815
# model:816
# model:817
# 817
# model:818
# 818
# model:819
# model:820
# model:821
# 821
# model:822
# model:823
# 823
# model:824
# 824
# model:825
# model:826
# 826
# model:827
# 827
# model:828
# 828
# model:829
# 829
# model:830
# model:831
# model:832
# model:833
# 833
# model:834
# 834
# model:835
# 835
# model:836
# model:837
# model:838
# model:839
# model:840
# model:841
# model:842
# model:843
# model:844
# model:845
# 845
# model:846
# 846
# model:847
# model:848
# model:849
# model:850
# model:851
# model:852
# model:853
# model:854
# model:855
# model:856
# model:857
# model:858
# model:859
# model:860
# model:861
# 861
# model:862
# 862
# model:863
# model:864
# model:865
# model:866
# model:867
# model:868
# model:869
# model:870
# 870
# model:871
# 871
# model:872
# model:873
# model:874
# model:875
# model:876
# model:877
# 877
# model:878
# 878
# model:879
# model:880
# model:881
# model:882
# model:883
# model:884
# model:885
# 885
# model:886
# 886
# model:887
# model:888
# 888
# model:889
# model:890
# 890
# model:891
# 891
# model:892
# 892
# model:893
# 893
# model:894
# model:895
# model:896
# model:897
# model:898
# model:899
# model:900
# 900
# model:901
# 901
# model:902
# 902
# model:903
# 903
# model:904
# model:905
# model:906
# model:907
# model:908
# model:909
# model:910
# model:911
# 911
# model:912
# 912
# model:913
# model:914
# model:915
# model:916
# model:917
# model:918
# 918
# model:919
# 919
# model:920
# model:921
# model:922
# 922
# model:923
# 923
# model:924
# 924
# model:925
# model:926
# model:927
# model:928
# 928
# model:929
# 929
# model:930
# 930
# model:931
# 931
# model:932
# 932
# model:933
# 933
# model:934
# model:935
# 935
# model:936
# 936
# model:937
# 937
# model:938
# 938
# model:939
# model:940
# 940
# model:941
# 941
# model:942
# 942
# model:943
# 943
# model:944
# model:945
# model:946
# 946
# model:947
# 947
# model:948
# 948
# model:949
# model:950
# 950
# model:951
# 951
# model:952
# 952
# model:953
# model:954
# model:955
# 955
# model:956
# model:957
# model:958
# model:959
# 959
# model:960
# 960
# model:961
# 961
# model:962
# model:963
# 963
# model:964
# 964
# model:965
# 965
# model:966
# model:967
# model:968
# 968
# model:969
# 969
# model:970
# model:971
# 971
# model:972
# 972
# model:973
# model:974
# 974
# model:975
# model:976
# 976
# model:977
# model:978
# 978
# model:979
# 979
# model:980
# model:981
# 981
# model:982
# 982
# model:983
# 983
# model:984
# model:985
# model:986
# model:987
# model:988
# model:989
# 989
# model:990
# model:991
# model:992
# model:993
# model:994
# model:995
# model:996
# model:997
# model:998
# model:999
# 69.34345650672913
# 452

# %%
import numpy as np
# use the generated stage index for prediction
def predict_single_item_with_stage_model(model, data):
    totalSize = len(data)+1
    predicted_y = []
    tempy = 0
    modelIndex = 0
    for m in range(len(model)):
        tempy = model[m][modelIndex].predict(data)
#         tempy = model[m][modelIndex].predict(data.iloc[i,:].reshape(1,-1))
#         tempy = model[m][modelIndex].predict(data.iloc[i,])
        if tempy < 0:
            tempy = 0
        if tempy >= totalSize:
            tempy = totalSize-1
        if m < len(model)-1:
            modelIndex = int((tempy/totalSize)*len(model[m+1]))
    return temoy

# %%
def find_discrepancy(hilbert_value, df, position):
    true_hilbert_value = df.iloc[position,4]
    cost = 0
    dif_first = 0
    dif_next = 0
    dif_first = abs(true_hilbert_value-hilbert_value)
    if dif_first == 0:
        return 0
    cost += 1
    while True:
        if true_hilbert_value < hilbert_value:
            true_hilbert_value = df.iloc[position+cost,4]
            dif_next = abs(true_hilbert_value-hilbert_value)
            if dif_next > dif_first:
                return cost-1
        else:
            true_hilbert_value = df.iloc[position-cost,4]
            dif_next = abs(true_hilbert_value-hilbert_value)
            if dif_next > dif_first:
                return cost-1

# %%
cost1 = find_discrepancy(-2.103575, df, 0)
print(cost1)

# %%
def range_query(lower_x, upper_x, lower_y, upper_y,max_bits = 22, print_intervals = False, print_cost = False, model = None, df = None, scaler = None):
    lx = int((2*lower_x+180)*10000) >> 22-max_bits
    ly = int((lower_y+180)*10000) >> 22-max_bits
    ux = int((2*upper_x+180)*10000) >> 22-max_bits
    uy = int((upper_y+180)*10000) >> 22-max_bits
    
    intervals = get_intervals(lx,ux,ly,uy,max_bits)
    total_size = len(intervals)
    print("total intervals: ",total_size)
    if print_intervals:
        print(intervals)
    if print_cost:
        cost = 0
        for interval in intervals:
            
            df1 = pd.DataFrame(data=[[lower_x,lower_y,lx,ly,interval["lower_hilbert"]]], columns=["x","y","x_","y_","hilbert"],index=[0], dtype=object)
            df1.iloc[0,:] = scaler.transform(df1.iloc[0,:].reshape(1,-1))
            predicted_position1 = predict_single_item_with_stage_model(df1[0,4])
            
            df2 = pd.DataFrame(data=[[upper_x,upper_y,ux,uy,interval["upper_hilbert"]]], columns=["x","y","x_","y_","hilbert"],index=[0], dtype=object)
            df2.iloc[0,:] = scaler.transform(df2.iloc[0,:].reshape(1,-1))
            predicted_position2 = predict_single_item_with_stage_model(df2[0,4])
            
            cost1 = find_discrepancy(df1.iloc[0,4], df, predicted_position1)
            cost2 = find_discrepancy(df2.iloc[0,4], df, predicted_position2)
            
            cost += cost1
            cost += cost2
        print("total cost: ",cost)

# %%
# import ipdb
# ipdb.set_trace()
# range_query(1, 2, 1, 2,14)
# range_query(1, 10, 1, 10,14)
# range_query(-10, 10, -10, 10,14)
# range_query(-20, 20, -20, 20,14)
# range_query(-30, 30, -30, 30,14)
# range_query(-40, 40, -40, 40,14)
# range_query(-15.1234,17.1983,-13.1677,11.8765,14)

# range_query(38.7900,39.0118,-77.2123,-76.8835,14) # Washington DC
# range_query(22.1481,22.5457,113.8436,114.4379,14) # Hong Kong
# range_query(22.2201,22.2841,114.1278,114.2572,14) # Hong Kong island

range_query(38.7900,39.0118,-77.2123,-76.8835,14,False,True,index,df) # Washington DC
range_query(22.1481,22.5457,113.8436,114.4379,14,False,True,index,df) # Hong Kong
range_query(22.2201,22.2841,114.1278,114.2572,14,False,True,index,df) # Hong Kong island
# Out:
# total intervals:  52
# total intervals:  534
# total intervals:  794
# total intervals:  2218
# total intervals:  3041
# total intervals:  3474
# total intervals:  1109

# %%
import csv
HILBERT_N = 4194306 # 4 Million
list = []
count = -1
with open("./Data/SortedPOIs.csv", newline='') as csvfile:
    spamreader = csv.reader(csvfile)
    for row in spamreader:
        if count == -1: # ignore the head info
            count += 1
            continue
        x = float(row[0])
        y = float(row[1])
        x_ = int((2*x+180)*10000)
        y_ = int((y+180)*10000)
        h_ = xy2d(HILBERT_N,x_, y_)
        list.append([x,y,x_,y_,h_,count])
        count += 1
        if count % 10000 == 0:
            print(count)

# %%
import csv
def write_csv_file(path, head, data):  
    try:  
        with open(path, 'w', newline='') as csv_file:  
            writer = csv.writer(csv_file, dialect='excel')  
  
            if head is not None:  
                writer.writerow(head)  
  
            for row in data:  
                writer.writerow(row)  
  
            print("Write a CSV file to path %s Successful." % path)  
    except Exception as e:  
        print("Write an CSV file to path: %s, Case: %s" % (path, e))

# %%
list.sort(key = lambda x:(x[4]))
for i in  range(len(list)):
    list[i][5] = i
write_csv_file("./Data/HilbertSortedPOIs.csv",['x','y','x_','y_','hilbert','order','prediction'],list)
